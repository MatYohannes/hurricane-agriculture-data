# %% [markdown]
# # Impact of Hurricanes on the Agriculture Sector
#
# ### An Exploratory Data Analysis
#
# ---
#
# **Author:** Mathewos Yohannes
# **Date:** October 2024
#
# ---
#
# ## Overview
#
# This project analyzes the impact of hurricanes on the agriculture sector by examining historical data from commodities, economic indicators, inflation rates, and stock performance during significant hurricane years: 2005, 2017, 2021, 2022, and the ongoing 2024 hurricane season. The primary purpose of this analysis is to compare the market response during the 2024 hurricane season with past hurricane seasons, identifying any significant trends or changes in the agriculture sector.
#
# ---
#
# ## Table of Contents
#
# 1. [Introduction](#Introduction)
# 2. [Data Sources](#Data-Sources)
# 3. [Methodology](#Methodology)
# 4. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
#     - Commodities
#     - Economic Indicators
#     - Inflation
#     - Stocks
# 5. [Insights](#Insights)
# 6. [Conclusion](#Conclusion)

# %% [markdown]
# ## Introduction
#
# Natural disasters, such as hurricanes, have a profound impact on global markets, particularly in sectors like agriculture, which are highly sensitive to weather conditions. This project seeks to understand how the agriculture sector has responded to major hurricanes across different years: 2005, 2017, 2021, 2022, and the ongoing 2024 hurricane season. By analyzing data from various sources—commodities prices, economic indicators, inflation rates, and stock performances—we aim to uncover trends that demonstrate the economic impact of these natural events on the agriculture sector.
#
# The 2024 hurricane season has been especially disruptive, and it offers an opportunity to compare its effects to past hurricanes, allowing for insights into market behavior, commodity pricing, and broader economic implications. This analysis will provide stakeholders with valuable data-driven insights into how the agriculture sector may respond in future disaster scenarios.
#
# The following sections detail the data sources used, the methodology employed, and the analysis conducted to explore the economic consequences of these events.

# %% [markdown]
# ## Data Sources
#
# This project leverages multiple data sources to gather relevant information for the analysis:
#
# 1. **Alpha Vantage API**
#    [Alpha Vantage](https://www.alphavantage.co/) was used to retrieve stock market data for the top 50 agriculture-related stocks that could potentially be affected by hurricanes in the southeastern U.S. This list includes companies involved in farming, food production, agricultural machinery, fertilizers, and other related industries. The API provided us with historical stock prices, which were essential for understanding the market response to hurricane events over the years.
#
# 2. **List of Costliest Atlantic Hurricanes**
#    [Wikipedia](https://en.wikipedia.org/wiki/List_of_costliest_Atlantic_hurricanes) was used to gather historical information on the most financially damaging hurricanes in the Atlantic. This helped identify key years for the analysis, including 2005, 2017, 2021, 2022, and 2024.
#
# 3. **Additional Resources on Major Hurricanes**
#    Several websites were referenced to provide a deeper understanding of the hurricanes that had the greatest impact on the agriculture sector and the U.S. economy:
#
#    - [Time: Strongest Hurricanes in U.S. History](https://time.com/6218275/strongest-hurricanes-us-map/)
#    - [CBS News: Most Destructive Hurricanes in U.S. History](https://www.cbsnews.com/news/most-desctructive-hurricanes-us-history-pictures-devastation/)
#    - [Reuters: Most Devastating Hurricanes in U.S. History](https://www.reuters.com/pictures/most-devastating-hurricanes-us-history-2024-09-26/)
#
# 4. **The Most Lucrative Food CXrop in Each State**
#    [https://vividmaps.com/mapping-the-most-valuable-agricultural-commodity-in-each-u-s-state/]
# These sources collectively provide the foundational data required for analyzing the economic impact of hurricanes on the agriculture sector in various years.

# %% [markdown]
# ## Methodology
#
# ### Data Collection
# Data for this project was primarily collected using the Alpha Vantage API, which provided historical stock data for the following agriculture-related companies that could potentially be affected by hurricanes in the southeastern U.S.:
# - "ADM"   # Archer-Daniels-Midland Company
# - "BG"    # Bunge Limited
# - "CTVA"  # Corteva, Inc.
# - "DE"    # Deere & Company
# - "TSN"   # Tyson Foods, Inc.
# - "MOS"   # Mosaic Company
# - "CF"    # CF Industries Holdings, Inc.
# - "AGCO"  # AGCO Corporation
# - "PPC"   # Pilgrim's Pride Corporation
# - "CALM"  # Cal-Maine Foods, Inc.
# - "INGR"  # Ingredion Incorporated
# - "FDP"   # Fresh Del Monte Produce Inc.
# - "ANDE"  # Andersons, Inc.
# - "LNN"   # Lindsay Corporation
# - "SMG"   # Scotts Miracle-Gro Company
# - "CVGW"  # Calavo Growers, Inc.
# - "DAR"   # Darling Ingredients Inc.
# - "SEB"   # Seaboard Corporation
# - "HRL"   # Hormel Foods Corporation
# - "TSCO"  # Tractor Supply Company
# - "CAG"   # Conagra Brands, Inc.
# - "MKC"   # McCormick & Company, Incorporated
# - "HOGS"  # Zhongpin Inc.
# - "SYY"   # Sysco Corporation
# - "BRFS"  # BRF S.A.
# - "HAIN"  # Hain Celestial Group, Inc.
# - "MDLZ"  # Mondelez International, Inc.
# - "UL"    # Unilever PLC
# - "KHC"   # Kraft Heinz Company
# - "JBSAY" # JBS S.A.
# - "PFGC"  # Performance Food Group Company
# - "SENEA" # Seneca Foods Corporation
# - "FLO"   # Flowers Foods, Inc.
# - "LANC"  # Lancaster Colony Corporation
# - "POST"  # Post Holdings, Inc.
# - "JVA"   # Coffee Holding Co., Inc.
# - "STKL"  # SunOpta Inc.
# - "SMPL"  # The Simply Good Foods Company
# - "THS"   # TreeHouse Foods, Inc.
# - "UNFI"  # United Natural Foods, Inc.
# - "WW"    # WW International, Inc.
# - "BGS"   # B&G Foods, Inc.
# - "JJSF"  # J&J Snack Foods Corp.
# - "ALCO"  # Alico, Inc.
#
# Additionally, economic indicators such as Consumer Price Index (CPI), Retail Sales, Unemployment Rates, and Nonfarm Payroll data were retrieved for the same time periods.
#
# Commodities data for wheat, corn, cotton, sugar, and coffee was also collected monthly using the Alpha Vantage API. The impact of hurricanes on commodity prices is a key focus of this analysis. The Wikipedia page on the [List of Costliest Atlantic Hurricanes](https://en.wikipedia.org/wiki/List_of_costliest_Atlantic_hurricanes) and other sources were consulted to identify hurricanes with significant economic impacts.
#
# ### Data Preprocessing
# The raw data was preprocessed to clean and format it for analysis. This involved:
# - Handling missing values in stock prices and economic indicators.
# - Converting string date fields into timestamp format for consistency across datasets.
# - Normalizing numeric fields such as stock prices and inflation rates to ensure comparability.
#
# ### Data Storage and Access
# Data was stored in an AWS S3 bucket, organized into folders based on the type of data (commodities, economic indicators, stocks, and inflation). AWS Athena was used to query the data efficiently, with tables created for each dataset.
#
# Each table was structured to ensure compatibility across different data sources:
# - The stock data was stored with columns for date, stock symbol, open, high, low, close, and volume.
# - Economic indicators and commodities were stored with date and value fields.
#
# ### Exploratory Data Analysis (EDA)
# Initial exploration of the data was performed using Jupyter Notebook. Python libraries such as Pandas and Seaborn were used to:
# - Generate summary statistics.
# - Plot time series data to observe trends over time.
# - Identify any correlations between stock performance, economic indicators, and commodity prices during and after hurricane events.
#
# ### Data Visualization
# Tableau was used to create interactive dashboards that visually represent the impact of hurricanes across multiple years. Visualizations include:
# - Time series plots comparing stock prices and commodity values over different hurricane seasons.
# - Heatmaps to identify years with the highest economic impact.
#
# ### Comparative Analysis
# A key focus of this project was to compare the ongoing 2024 hurricane season with previous hurricane seasons (2005, 2017, 2021, and 2022). This involved comparing the financial performance of the agriculture sector, changes in commodity prices, and fluctuations in economic indicators across these periods.
#
# ### Tools and Technologies
# The following tools and technologies were used in the project:
# - **Data Extraction**: Alpha Vantage API
# - **Data Storage**: AWS S3, AWS Athena
# - **Data Analysis**: Jupyter Notebook, Python (Pandas, Matplotlib, Seaborn)
# - **Data Visualization**: Tableau

# %% [markdown]
# ## Exploratory-Data-Analysis

# %%
from pyathena import connect
import pandas as pd

# Set up the connection to Athena
conn = connect(
    s3_staging_dir='s3://hurricane-agriculture-data/athena-queries/Unsaved/2024/10/13/',
    region_name='us-west-1',  # Update with your region
    schema_name='hurricane_agriculture_db'
)

# %% [markdown]
# ## Inflation

# %%
# Query to retrieve inflation data
inflation_query = """
SELECT * FROM inflation
"""
inflation_df = pd.read_sql(inflation_query, conn)

# Display the first few rows of the DataFrame
inflation_df.head()
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_20992\1116093373.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   inflation_df = pd.read_sql(inflation_query, conn)
#          date  inflation_rate
# 0  2023-01-01        4.116338
# 1  2022-01-01        8.002800
# 2  2021-01-01        4.697859
# 3  2020-01-01        1.233584
# 4  2019-01-01        1.812210

# %%
inflation_df.describe()
# Out:
#        inflation_rate
# count       64.000000
# mean         3.770332
# std          2.762789
# min         -0.355546
# 25%          1.876588
# 50%          3.021948
# 75%          4.399867
# max         13.549202

# %%
inflation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            64 non-null     object
#  1   inflation_rate  64 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
# Convert 'date' column to datetime format
inflation_df['date'] = pd.to_datetime(inflation_df['date'])

# %%
inflation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            64 non-null     datetime64[ns]
#  1   inflation_rate  64 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB

# %%
# Check for missing values
missing_values_inf = inflation_df.isnull().sum()
print(missing_values_inf)
# Out:
# date              0
# inflation_rate    0
# dtype: int64

# %%
inflation_df.describe()
# Out:
#                       date  inflation_rate
# count                   64       64.000000
# mean   1991-07-02 18:00:00        3.770332
# min    1960-01-01 00:00:00       -0.355546
# 25%    1975-10-01 18:00:00        1.876588
# 50%    1991-07-02 12:00:00        3.021948
# 75%    2007-04-02 06:00:00        4.399867
# max    2023-01-01 00:00:00       13.549202
# std                    NaN        2.762789

# %%
# Filter the DataFrame for the date range from 2000 to present
filtered_inflation_df = inflation_df[(inflation_df['date'] >= '2000-01-01')]

# %%
# Adjusting date column to only include the year
filtered_inflation_df['year'] = pd.DatetimeIndex(filtered_inflation_df['date']).year
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_20992\367896575.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_inflation_df['year'] = pd.DatetimeIndex(filtered_inflation_df['date']).year

# %%
filtered_inflation_df.tail(10)
# Out:
#          date  inflation_rate  year
# 14 2009-01-01       -0.355546  2009
# 15 2008-01-01        3.839100  2008
# 16 2007-01-01        2.852673  2007
# 17 2006-01-01        3.225944  2006
# 18 2005-01-01        3.392747  2005
# 19 2004-01-01        2.677237  2004
# 20 2003-01-01        2.270095  2003
# 21 2002-01-01        1.586032  2002
# 22 2001-01-01        2.826171  2001
# 23 2000-01-01        3.376857  2000

# %% [markdown]
# ### Exploratory Data Analysis (EDA) on Commodities
#
# ### Overview
# In this section, we will conduct exploratory data analysis on the commodities data collected. Our goal is to understand the trends, patterns, and relationships in the data, particularly in relation to the impact of hurricanes on commodity prices.
#
# ### Install necessary packages
# ```python
# pip install pyathena pandas matplotlib seaborn
# ```

# %% [markdown]
# ### Establish a connection to AWS Athena
# First, we will load the commodities data from AWS Athena.

# %% [markdown]
# ### Loading the Commodities Data
# First, we will load the commodities data from AWS Athena into a Pandas DataFrame for analysis.

# %%
# Query to retrieve commodities data
commodities_query = """
SELECT * FROM commodities
"""
commodities_df = pd.read_sql(commodities_query, conn)

# Display the first few rows of the DataFrame
commodities_df.head()
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_20992\1551355482.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   commodities_df = pd.read_sql(commodities_query, conn)
#   commodity        date      value
# 0      CORN  2024-09-01  183.65582
# 1      CORN  2024-08-01  169.29674
# 2      CORN  2024-07-01  177.76772
# 3      CORN  2024-06-01  191.24094
# 4      CORN  2024-05-01  201.01947

# %%
commodities_df.describe()
# Out:
#              value
# count  2085.000000
# mean    115.170230
# std      80.342842
# min       5.111200
# 25%      58.615220
# 50%     104.278530
# 75%     163.071430
# max     444.156560

# %%
commodities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2685 entries, 0 to 2684
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   commodity  2685 non-null   object
#  1   date       2685 non-null   object
#  2   value      2085 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 63.1+ KB

# %%
# Convert 'date' column to datetime format
commodities_df['date'] = pd.to_datetime(commodities_df['date'])

# %%
commodities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2685 entries, 0 to 2684
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   commodity  2685 non-null   object
#  1   date       2685 non-null   datetime64[ns]
#  2   value      2085 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 63.1+ KB

# %%
# Check for missing values
missing_values_com = commodities_df.isnull().sum()
print(missing_values_com)
# Out:
# commodity      0
# date           0
# value        600
# dtype: int64

# %%
# Drop any rows with missing values (if necessary)
commodities_df.dropna(inplace=True)

# %%
missing_values_com_check = commodities_df.isnull().sum()
print(missing_values_com_check)
# Out:
# commodity    0
# date         0
# value        0
# dtype: int64

# %%
commodities_df.describe()
# Out:
#                                 date        value
# count                           2085  2085.000000
# mean   2007-05-02 04:01:43.597122304   115.170230
# min              1990-01-01 00:00:00     5.111200
# 25%              1998-09-01 00:00:00    58.615220
# 50%              2007-05-01 00:00:00   104.278530
# 75%              2016-01-01 00:00:00   163.071430
# max              2024-09-01 00:00:00   444.156560
# std                              NaN    80.342842

# %%
# Use pivot to reshape the DataFrame
pivoted_commodities_df = commodities_df.pivot(index='date', columns='commodity', values='value')

# %%
# Reset index to have date as a column instead of index
pivoted_commodities_df.reset_index(inplace=True)

# %%
pivoted_commodities_df.columns.name = None  # Remove the name of the columns
pivoted_commodities_df.columns = [f"{col}_value" if col != 'date' else 'date' for col in pivoted_commodities_df.columns]

# %%
pivoted_commodities_df.head(4)
# Out:
#         date  COFFEE_value  CORN_value  COTTON_value  SUGAR_value  WHEAT_value
# 0 1990-01-01      75.82999   105.90051     75.200010    14.200001    167.91858
# 1 1990-02-01      84.01001   106.29417     75.959990    14.650002    160.93727
# 2 1990-03-01      93.95999   109.83732     78.899994    15.310001    156.52803
# 3 1990-04-01      93.73001   118.49834     82.869995    15.240002    159.46753

# %%
# Change column names to lowercase
pivoted_commodities_df.columns = pivoted_commodities_df.columns.str.lower()

# %%
pivoted_commodities_df.columns
# Out:
# Index(['date', 'coffee_value', 'corn_value', 'cotton_value', 'sugar_value',
#        'wheat_value'],
#       dtype='object')

# %%
pivoted_commodities_df.head(2)
# Out:
#         date  coffee_value  corn_value  cotton_value  sugar_value  wheat_value
# 0 1990-01-01      75.82999   105.90051      75.20001    14.200001    167.91858
# 1 1990-02-01      84.01001   106.29417      75.95999    14.650002    160.93727

# %%
# Filter the DataFrame for the date range from 2000 to present
filtered_commodities_df = pivoted_commodities_df[(pivoted_commodities_df['date'] >= '2000-01-01')]

# %%
filtered_commodities_df.head(2)
# Out:
#           date  coffee_value  corn_value  cotton_value  sugar_value  \
# 120 2000-01-01    111.851425    92.95328     47.433334       5.6295
# 121 2000-02-01    104.041430    95.08162     53.435000       5.3510
#
#      wheat_value
# 120     93.62286
# 121     98.16683

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Visualization
# ### Commodities

# %% [markdown]
# ### Commodity Prices Over Time

# %%
# Plot the commodity values

# Set the date column as the index
filtered_commodities_df2 = filtered_commodities_df
filtered_commodities_df = filtered_commodities_df.set_index('date')

plt.figure(figsize=(12, 6))
plt.plot(filtered_commodities_df.index, filtered_commodities_df['coffee_value'], label='Coffee', color='brown')
plt.plot(filtered_commodities_df.index, filtered_commodities_df['corn_value'], label='Corn', color='yellow')
plt.plot(filtered_commodities_df.index, filtered_commodities_df['cotton_value'], label='Cotton', color='blue')
plt.plot(filtered_commodities_df.index, filtered_commodities_df['sugar_value'], label='Sugar', color='orange')
plt.plot(filtered_commodities_df.index, filtered_commodities_df['wheat_value'], label='Wheat', color='green')

plt.title('Commodity Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
filtered_commodities_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 120 to 416
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          297 non-null    datetime64[ns]
#  1   coffee_value  297 non-null    float64
#  2   corn_value    297 non-null    float64
#  3   cotton_value  297 non-null    float64
#  4   sugar_value   297 non-null    float64
#  5   wheat_value   297 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 16.2 KB

# %% [markdown]
# ## Grouping and Aggregating Data

# %%
#Resample the data to calculate year averages
yearly_avg_commodities = filtered_commodities_df.resample('YE').mean()
yearly_avg_commodities['year'] = yearly_avg_commodities.index.year
yearly_avg_commodities
# Out:
#             coffee_value  corn_value  cotton_value  sugar_value  wheat_value  \
# date
# 2000-12-31     87.204111   88.219229     59.047716     8.079842   100.739015
# 2001-12-31     62.284133   89.609138     47.996912     8.231553   106.372979
# 2002-12-31     61.462067   99.333267     46.260130     6.236949   132.167459
# 2003-12-31     64.172862  105.245363     63.445350     6.925712   131.918757
# 2004-12-31     80.479525  111.894866     62.005999     7.545098   134.390884
# 2005-12-31    114.853918   98.507652     55.168262    10.070184   129.673830
# 2006-12-31    114.408858  121.647392     58.052463    14.788470   169.138637
# 2007-12-31    123.613877  163.609891     63.283692     9.956637   231.184936
# 2008-12-31    139.712465  223.360288     71.399863    12.452207   292.967477
# 2009-12-31    143.754759  165.628349     62.752035    18.150361   192.107476
# 2010-12-31    196.049092  185.956506    103.543724    20.890925   195.229900
# ...

# %%
commodities_inflation_adjusted = pd.merge(yearly_avg_commodities, filtered_inflation_df[['year', 'inflation_rate']], on='year', how='left')

commodities_inflation_adjusted.set_index('year', inplace=True)
commodities_inflation_adjusted
# Out:
#       coffee_value  corn_value  cotton_value  sugar_value  wheat_value  \
# year
# 2000     87.204111   88.219229     59.047716     8.079842   100.739015
# 2001     62.284133   89.609138     47.996912     8.231553   106.372979
# 2002     61.462067   99.333267     46.260130     6.236949   132.167459
# 2003     64.172862  105.245363     63.445350     6.925712   131.918757
# 2004     80.479525  111.894866     62.005999     7.545098   134.390884
# 2005    114.853918   98.507652     55.168262    10.070184   129.673830
# 2006    114.408858  121.647392     58.052463    14.788470   169.138637
# 2007    123.613877  163.609891     63.283692     9.956637   231.184936
# 2008    139.712465  223.360288     71.399863    12.452207   292.967477
# 2009    143.754759  165.628349     62.752035    18.150361   192.107476
# 2010    196.049092  185.956506    103.543724    20.890925   195.229900
# 2011    271.108057  291.854082    154.983130    26.235583   280.282474
# ...

# %%
# Adjust each commodity value for inflation by dividing by (1 + inflation_rate/100)
commodities_inflation_adjusted['coffee_value_adjusted'] = commodities_inflation_adjusted['coffee_value'] / (1 + commodities_inflation_adjusted['inflation_rate'] / 100)
commodities_inflation_adjusted['corn_value_adjusted'] = commodities_inflation_adjusted['corn_value'] / (1 + commodities_inflation_adjusted['inflation_rate'] / 100)
commodities_inflation_adjusted['cotton_value_adjusted'] = commodities_inflation_adjusted['cotton_value'] / (1 + commodities_inflation_adjusted['inflation_rate'] / 100)
commodities_inflation_adjusted['sugar_value_adjusted'] = commodities_inflation_adjusted['sugar_value'] / (1 + commodities_inflation_adjusted['inflation_rate'] / 100)
commodities_inflation_adjusted['wheat_value_adjusted'] = commodities_inflation_adjusted['wheat_value'] / (1 + commodities_inflation_adjusted['inflation_rate'] / 100)

# Display the updated dataframe with inflation-adjusted columns
commodities_inflation_adjusted.head(5)
Then
# Out:
#       coffee_value  corn_value  cotton_value  sugar_value  wheat_value  \
# year
# 2000     87.204111   88.219229     59.047716     8.079842   100.739015
# 2001     62.284133   89.609138     47.996912     8.231553   106.372979
# 2002     61.462067   99.333267     46.260130     6.236949   132.167459
# 2003     64.172862  105.245363     63.445350     6.925712   131.918757
# 2004     80.479525  111.894866     62.005999     7.545098   134.390884
#
#       inflation_rate  coffee_value_adjusted  corn_value_adjusted  \
# year
# 2000        3.376857              84.355544            85.337503
# 2001        2.826171              60.572257            87.146236
# 2002        1.586032              60.502479            97.782408
# 2003        2.270095              62.748414           102.909226
# 2004        2.677237              78.381078           108.977286
#
#       cotton_value_adjusted  sugar_value_adjusted  wheat_value_adjusted
# year
# ...

# %% [markdown]
# Since inflation is compounded yearly, inflation is factored and commodity prices are compared over time relative to base year, 2000. The adjustment should account for cumulative inflation across mulitple years. This method is often reffered to as coverting prices to constant dollars (adjusting for inflation relative to base year). This provides a more accurate comparison of prices over time without the distortions caused by inflation.
#
# Adjusted Value = (commodity value) / (1 + cumulative inflation)

# %%
# Step 1: Create a cumulative inflation column starting from the base year (2000)
commodities_inflation_adjusted['cumulative_inflation'] = (1 + commodities_inflation_adjusted['inflation_rate'] / 100).cumprod()

# Step 2: Set the base year cumulative inflation to 1 (i.e., no adjustment needed for the base year)
commodities_inflation_adjusted.loc[2000, 'cumulative_inflation'] = 1

# Step 3: Adjust the commodity prices relative to the base year (2000) prices
commodities_inflation_adjusted['coffee_value_adjusted'] = commodities_inflation_adjusted['coffee_value'] / commodities_inflation_adjusted['cumulative_inflation']
commodities_inflation_adjusted['corn_value_adjusted'] = commodities_inflation_adjusted['corn_value'] / commodities_inflation_adjusted['cumulative_inflation']
commodities_inflation_adjusted['cotton_value_adjusted'] = commodities_inflation_adjusted['cotton_value'] / commodities_inflation_adjusted['cumulative_inflation']
commodities_inflation_adjusted['sugar_value_adjusted'] = commodities_inflation_adjusted['sugar_value'] / commodities_inflation_adjusted['cumulative_inflation']
commodities_inflation_adjusted['wheat_value_adjusted'] = commodities_inflation_adjusted['wheat_value'] / commodities_inflation_adjusted['cumulative_inflation']

# Display the updated dataframe with inflation-adjusted values
commodities_inflation_adjusted.head(5)
# Out:
#       coffee_value  corn_value  cotton_value  sugar_value  wheat_value  \
# year
# 2000     87.204111   88.219229     59.047716     8.079842   100.739015
# 2001     62.284133   89.609138     47.996912     8.231553   106.372979
# 2002     61.462067   99.333267     46.260130     6.236949   132.167459
# 2003     64.172862  105.245363     63.445350     6.925712   131.918757
# 2004     80.479525  111.894866     62.005999     7.545098   134.390884
#
#       inflation_rate  coffee_value_adjusted  corn_value_adjusted  \
# year
# 2000        3.376857              87.204111            88.219229
# 2001        2.826171              58.593634            84.299560
# 2002        1.586032              56.917547            91.988542
# 2003        2.270095              58.108781            95.300094
# 2004        2.677237              70.974377            98.679364
#
#       cotton_value_adjusted  sugar_value_adjusted  wheat_value_adjusted  \
# year
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['coffee_value_adjusted'], label='Coffee adjusted', color='brown')
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['corn_value_adjusted'], label='Corn adjusted', color='yellow')
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['cotton_value_adjusted'], label='Cotton adjusted', color='blue')
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['sugar_value_adjusted'], label='Sugar adjusted', color='orange')
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['wheat_value_adjusted'], label='Wheat adjusted', color='green')

plt.title('Commodity Adjusted Value, base year 2000')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Identifying Commodities Outliers

# %% [markdown]
# ### Outlier Months for Coffee Prices

# %%
# Calculate the IQR for coffee prices
Q1 = filtered_commodities_df['coffee_value'].quantile(0.25)
Q3 = filtered_commodities_df['coffee_value'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_coffee = filtered_commodities_df[(filtered_commodities_df['coffee_value'] < lower_bound) | (filtered_commodities_df['coffee_value'] > upper_bound)]['coffee_value']

# Display the outliers
print("Outliers in Coffee Prices:")
print(outliers_coffee)
# Out:
# Outliers in Coffee Prices:
# date
# 2011-03-01    292.06738
# 2011-04-01    300.47714
# 2011-05-01    291.06592
# Name: coffee_value, dtype: float64

# %%
# Calculate the IQR for coffee prices with inflation-adjusted with base year 2000
Q1 = commodities_inflation_adjusted['coffee_value_adjusted'].quantile(0.25)
Q3 = commodities_inflation_adjusted['coffee_value_adjusted'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_coffee_inflation_adjusted = commodities_inflation_adjusted[(commodities_inflation_adjusted['coffee_value_adjusted'] < lower_bound) | (commodities_inflation_adjusted['coffee_value_adjusted'] > upper_bound)]['coffee_value_adjusted']

# Display the outliers
print("Outliers in Coffee Prices with inflation-adjusted with base year 2000:")
print(outliers_coffee_inflation_adjusted)
# Out:
# Outliers in Coffee Prices with inflation-adjusted with base year 2000:
# year
# 2011    200.764611
# Name: coffee_value_adjusted, dtype: float64

# %% [markdown]
# ### Outlier Months for Corn Prices

# %%
# Calculate the IQR for corn prices
Q1 = filtered_commodities_df['corn_value'].quantile(0.25)
Q3 = filtered_commodities_df['corn_value'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_corn = filtered_commodities_df[(filtered_commodities_df['corn_value'] < lower_bound) | (filtered_commodities_df['corn_value'] > upper_bound)]['corn_value']

# Display the outliers
print("Outliers in Corn Prices:")
print(outliers_corn)
# Out:
# Outliers in Corn Prices:
# Series([], Name: corn_value, dtype: float64)

# %%
# Calculate the IQR for corn prices with inflation-adjusted with base year 2000
Q1 = commodities_inflation_adjusted['corn_value_adjusted'].quantile(0.25)
Q3 = commodities_inflation_adjusted['corn_value_adjusted'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_corn_inflation_adjusted = commodities_inflation_adjusted[(commodities_inflation_adjusted['corn_value_adjusted'] < lower_bound) | (commodities_inflation_adjusted['corn_value_adjusted'] > upper_bound)]['corn_value_adjusted']

# Display the outliers
print("Outliers in Corn Prices with inflation-adjusted with base year 2000:")
print(outliers_corn_inflation_adjusted)
# Out:
# Outliers in Corn Prices with inflation-adjusted with base year 2000:
# year
# 2011    216.127739
# 2012    216.522436
# Name: corn_value_adjusted, dtype: float64

# %% [markdown]
# ### Outlier Months for Cotton Prices

# %%
# Calculate the IQR for cotton prices
Q1 = filtered_commodities_df['cotton_value'].quantile(0.25)
Q3 = filtered_commodities_df['cotton_value'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_cotton = filtered_commodities_df[(filtered_commodities_df['cotton_value'] < lower_bound) | (filtered_commodities_df['cotton_value'] > upper_bound)]['cotton_value']

# Display the outliers
print("Outliers in Cotton Prices:")
print(outliers_cotton)
# Out:
# Outliers in Cotton Prices:
# date
# 2010-11-01    155.46819
# 2010-12-01    168.22382
# 2011-01-01    178.92750
# 2011-02-01    213.17500
# 2011-03-01    229.66739
# 2011-04-01    216.61667
# 2011-05-01    165.52000
# 2011-06-01    164.92500
# 2011-07-01    149.25000
# 2022-02-01    138.40500
# 2022-03-01    141.12608
# 2022-04-01    155.31580
# 2022-05-01    163.97954
# 2022-06-01    154.44545
# Name: cotton_value, dtype: float64

# %%
# Calculate the IQR for cotton prices with inflation-adjusted with base year 2000
Q1 = commodities_inflation_adjusted['cotton_value_adjusted'].quantile(0.25)
Q3 = commodities_inflation_adjusted['cotton_value_adjusted'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_cotton_inflation_adjusted = commodities_inflation_adjusted[(commodities_inflation_adjusted['cotton_value_adjusted'] < lower_bound) | (commodities_inflation_adjusted['cotton_value_adjusted'] > upper_bound)]['cotton_value_adjusted']

# Display the outliers
print("Outliers in Cotton Prices with inflation-adjusted with base year 2000:")
print(outliers_cotton_inflation_adjusted)
# Out:
# Outliers in Cotton Prices with inflation-adjusted with base year 2000:
# year
# 2010     79.098192
# 2011    114.770207
# Name: cotton_value_adjusted, dtype: float64

# %% [markdown]
# ### Outlier Months for Sugar Prices

# %%
# Calculate the IQR for sugar prices
Q1 = filtered_commodities_df['sugar_value'].quantile(0.25)
Q3 = filtered_commodities_df['sugar_value'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sugar = filtered_commodities_df[(filtered_commodities_df['sugar_value'] < lower_bound) | (filtered_commodities_df['sugar_value'] > upper_bound)]['sugar_value']

# Display the outliers
print("Outliers in Sugar Prices:")
print(outliers_sugar)
# Out:
# Outliers in Sugar Prices:
# Series([], Name: sugar_value, dtype: float64)

# %%
# Calculate the IQR for sugar prices with inflation-adjusted with base year 2000
Q1 = commodities_inflation_adjusted['sugar_value_adjusted'].quantile(0.25)
Q3 = commodities_inflation_adjusted['sugar_value_adjusted'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sugar_inflation_adjusted = commodities_inflation_adjusted[(commodities_inflation_adjusted['sugar_value_adjusted'] < lower_bound) | (commodities_inflation_adjusted['sugar_value_adjusted'] > upper_bound)]['sugar_value_adjusted']

# Display the outliers
print("Outliers in Sugar Prices with inflation-adjusted with base year 2000:")
print(outliers_sugar)
# Out:
# Outliers in Sugar Prices with inflation-adjusted with base year 2000:
# Series([], Name: sugar_value, dtype: float64)

# %% [markdown]
# ### Outlier Months for Wheat Prices

# %%
# Calculate the IQR for wheat prices
Q1 = filtered_commodities_df['wheat_value'].quantile(0.25)
Q3 = filtered_commodities_df['wheat_value'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_wheat = filtered_commodities_df[(filtered_commodities_df['wheat_value'] < lower_bound) | (filtered_commodities_df['wheat_value'] > upper_bound)]['wheat_value']

# Display the outliers
print("Outliers in Wheat Prices:")
print(outliers_wheat)
# Out:
# Outliers in Wheat Prices:
# date
# 2008-03-01    403.81290
# 2022-04-01    406.02690
# 2022-05-01    444.15656
# 2022-06-01    397.65230
# Name: wheat_value, dtype: float64

# %%
# Calculate the IQR for wheat prices with inflation-adjusted with base year 2000
Q1 = commodities_inflation_adjusted['wheat_value_adjusted'].quantile(0.25)
Q3 = commodities_inflation_adjusted['wheat_value_adjusted'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_wheat_inflation_adjusted = commodities_inflation_adjusted[(commodities_inflation_adjusted['wheat_value_adjusted'] < lower_bound) | (commodities_inflation_adjusted['wheat_value_adjusted'] > upper_bound)]['wheat_value_adjusted']

# Display the outliers
print("Outliers in Wheat Prices with inflation-adjusted with base year 2000:")
print(outliers_wheat_inflation_adjusted)
# Out:
# Outliers in Wheat Prices with inflation-adjusted with base year 2000:
# Series([], Name: wheat_value_adjusted, dtype: float64)

# %% [markdown]
# ## Checking for Commodities Trends

# %% [markdown]
# ### Rolling Average for Coffee Prices over a 12-month window

# %%
# Calculate rolling average for coffee prices over a 12-month window
filtered_commodities_df['coffee_rolling_avg'] = filtered_commodities_df['coffee_value'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(filtered_commodities_df.index, filtered_commodities_df['coffee_value'], label='Coffee Prices', color='grey', alpha=0.5)
plt.plot(filtered_commodities_df.index, filtered_commodities_df['coffee_rolling_avg'], label='12-Month Rolling Average', color='red')

plt.title('Coffee Prices with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate rolling average for coffee prices over a 12-month window with inflation-adjusted with base year 2000
commodities_inflation_adjusted['coffee_rolling_avg_infl_adj'] = commodities_inflation_adjusted['coffee_value_adjusted'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['coffee_value_adjusted'], label='Coffee Prices', color='grey', alpha=0.5)
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['coffee_rolling_avg_infl_adj'], label='12-Month Rolling Average', color='red')

plt.title('Coffee Prices with Rolling Average with inflation-adjusted with base year 2000')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Rolling Average for Corn Prices over a 12-month window

# %%
# Calculate rolling average for corn prices over a 12-month window
filtered_commodities_df['corn_rolling_avg'] = filtered_commodities_df['corn_value'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(filtered_commodities_df.index, filtered_commodities_df['corn_value'], label='Corn Prices', color='grey', alpha=0.5)
plt.plot(filtered_commodities_df.index, filtered_commodities_df['corn_rolling_avg'], label='12-Month Rolling Average', color='yellow')

plt.title('Corn Prices with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate rolling average for corn prices over a 12-month window with inflation-adjusted with base year 2000
commodities_inflation_adjusted['corn_rolling_avg_infl_adj'] = commodities_inflation_adjusted['corn_value_adjusted'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['corn_value_adjusted'], label='Corn Prices', color='grey', alpha=0.5)
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['corn_rolling_avg_infl_adj'], label='12-Month Rolling Average', color='yellow')

plt.title('Corn Prices with Rolling Average with inflation-adjusted with base year 2000')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Rolling Average for Cotton Prices over a 12-month window

# %%
# Calculate rolling average for cotton prices over a 12-month window
filtered_commodities_df['cotton_rolling_avg'] = filtered_commodities_df['cotton_value'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(filtered_commodities_df.index, filtered_commodities_df['cotton_value'], label='Cotton Prices', color='grey', alpha=0.5)
plt.plot(filtered_commodities_df.index, filtered_commodities_df['cotton_rolling_avg'], label='12-Month Rolling Average', color='blue')

plt.title('Cotton Prices with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate rolling average for cotton prices over a 12-month window with inflation-adjusted with base year 2000
commodities_inflation_adjusted['cotton_rolling_avg_infl_adj'] = commodities_inflation_adjusted['cotton_value_adjusted'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['cotton_value_adjusted'], label='Cotton Prices', color='grey', alpha=0.5)
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['cotton_rolling_avg_infl_adj'], label='12-Month Rolling Average', color='blue')

plt.title('Cotton Prices with Rolling Average with inflation-adjusted with base year 2000')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Rolling Average for Sugar Prices over a 12-month window

# %%
# Calculate rolling average for sugar prices over a 12-month window
filtered_commodities_df['sugar_rolling_avg'] = filtered_commodities_df['sugar_value'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(filtered_commodities_df.index, filtered_commodities_df['sugar_value'], label='Sugar Prices', color='grey', alpha=0.5)
plt.plot(filtered_commodities_df.index, filtered_commodities_df['sugar_rolling_avg'], label='12-Month Rolling Average', color='orange')

plt.title('Sugar Prices with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate rolling average for sugar prices over a 12-month window with inflation-adjusted with base year 2000 
commodities_inflation_adjusted['sugar_rolling_avg_infl_adj'] = commodities_inflation_adjusted['sugar_value_adjusted'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['sugar_value_adjusted'], label='Sugar Prices', color='grey', alpha=0.5)
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['sugar_rolling_avg_infl_adj'], label='12-Month Rolling Average', color='orange')

plt.title('Sugar Prices with Rolling Average with inflation-adjusted with base year 2000')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Rolling Average for Wheat Prices over a 12-month window

# %%
# Calculate rolling average for wheat prices over a 12-month window
filtered_commodities_df['wheat_rolling_avg'] = filtered_commodities_df['wheat_value'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(filtered_commodities_df.index, filtered_commodities_df['wheat_value'], label='Wheat Prices', color='grey', alpha=0.5)
plt.plot(filtered_commodities_df.index, filtered_commodities_df['wheat_rolling_avg'], label='12-Month Rolling Average', color='green')

plt.title('Wheat Prices with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate rolling average for wheat prices over a 12-month window with inflation-adjusted with base year 2000 
commodities_inflation_adjusted['wheat_rolling_avg_infl_adj'] = commodities_inflation_adjusted['wheat_value_adjusted'].rolling(window=12).mean()

# Plot the rolling average
plt.figure(figsize=(12, 6))
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['wheat_value_adjusted'], label='Wheat Prices', color='grey', alpha=0.5)
plt.plot(commodities_inflation_adjusted.index, commodities_inflation_adjusted['wheat_rolling_avg_infl_adj'], label='12-Month Rolling Average', color='green')

plt.title('Wheat Prices with Rolling Average with inflation-adjusted with base year 2000 ')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Loading the Economic indicators Data
# First, we will load the economic indicators data from AWS Athena into a Pandas DataFrame for analysis.

# %%
# Query to retrieve economic indicators data
economic_indicators_query = """
SELECT * FROM economic_indicators
"""
economic_indicators_df = pd.read_sql(economic_indicators_query, conn)

# Display the first few rows of the DataFrame
economic_indicators_df.head()
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_20992\380825590.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   economic_indicators_df = pd.read_sql(economic_indicators_query, conn)
#   indicator        date    value
# 0       CPI  2024-09-01  315.301
# 1       CPI  2024-08-01  314.796
# 2       CPI  2024-07-01  314.540
# 3       CPI  2024-06-01  314.175
# 4       CPI  2024-05-01  314.069

# %%
economic_indicators_df.describe()
# Out:
#                value
# count    3683.000000
# mean    61448.892591
# std    112162.163299
# min         2.500000
# 25%        10.000000
# 50%       125.000000
# 75%     89800.500000
# max    668957.000000

# %%
economic_indicators_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   indicator  3683 non-null   object
#  1   date       3683 non-null   object
#  2   value      3683 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 86.4+ KB

# %%
# Convert 'date' column to datetime format
economic_indicators_df['date'] = pd.to_datetime(economic_indicators_df['date'])

# %%
economic_indicators_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   indicator  3683 non-null   object
#  1   date       3683 non-null   datetime64[ns]
#  2   value      3683 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 86.4+ KB

# %%
# Check for missing values
missing_values_econ_ind = economic_indicators_df.isnull().sum()
print(missing_values_econ_ind)
# Out:
# indicator    0
# date         0
# value        0
# dtype: int64

# %%
# Use pivot to reshape the DataFrame
pivoted_econ_indicator_df = economic_indicators_df.pivot(index='date', columns='indicator', values='value')

# %%
# Reset index to have date as a column instead of index
pivoted_econ_indicator_df.reset_index(inplace=True)

# %%
pivoted_econ_indicator_df.columns.name = None  # Remove the name of the columns
pivoted_econ_indicator_df.columns = [f"{col}_value" if col != 'date' else 'date' for col in pivoted_econ_indicator_df.columns]

# %%
pivoted_econ_indicator_df.tail()
# Out:
#            date  CPI_value  NONFARM_PAYROLL_value  RETAIL_SALES_value  \
# 1336 2024-05-01    314.069               158842.0            643843.0
# 1337 2024-06-01    314.175               159341.0            604360.0
# 1338 2024-07-01    314.540               158399.0            629023.0
# 1339 2024-08-01    314.796               158717.0            637747.0
# 1340 2024-09-01    315.301               159177.0                 NaN
#
#       UNEMPLOYMENT_value
# 1336                 4.0
# 1337                 4.1
# 1338                 4.3
# 1339                 4.2
# 1340                 4.1

# %%
# Change column names to lowercase
pivoted_econ_indicator_df.columns = pivoted_econ_indicator_df.columns.str.lower()

# %%
pivoted_econ_indicator_df.columns = ['date', 'cpi_index', 'nonfarm_payroll_per_thousand', 'retail_sale_per_millions$', 'unemployment_percentage']
pivoted_econ_indicator_df.columns
# Out:
# Index(['date', 'cpi_index', 'nonfarm_payroll_per_thousand',
#        'retail_sale_per_millions$', 'unemployment_percentage'],
#       dtype='object')

# %%
# Filter the DataFrame for the date range from 2000 to present
filtered_econ_indicator_df = pivoted_econ_indicator_df[(pivoted_econ_indicator_df['date'] >= '2000-01-01')]

# %%
filtered_econ_indicator_df.head()
# Out:
#            date  cpi_index  nonfarm_payroll_per_thousand  \
# 1044 2000-01-01      168.8                      128993.0
# 1045 2000-02-01      169.8                      129655.0
# 1046 2000-03-01      171.2                      130752.0
# 1047 2000-04-01      171.3                      131749.0
# 1048 2000-05-01      171.5                      132706.0
#
#       retail_sale_per_millions$  unemployment_percentage
# 1044                   213709.0                      4.0
# 1045                   227087.0                      4.1
# 1046                   253717.0                      4.0
# 1047                   239051.0                      3.8
# 1048                   257581.0                      4.0

# %%
filtered_econ_indicator_df.set_index('date', inplace=True)

# %%
filtered_econ_indicator_df.head()
# Out:
#             cpi_index  nonfarm_payroll_per_thousand  \
# date
# 2000-01-01      168.8                      128993.0
# 2000-02-01      169.8                      129655.0
# 2000-03-01      171.2                      130752.0
# 2000-04-01      171.3                      131749.0
# 2000-05-01      171.5                      132706.0
#
#             retail_sale_per_millions$  unemployment_percentage
# date
# 2000-01-01                   213709.0                      4.0
# 2000-02-01                   227087.0                      4.1
# 2000-03-01                   253717.0                      4.0
# 2000-04-01                   239051.0                      3.8
# 2000-05-01                   257581.0                      4.0

# %% [markdown]
# ## Identifying Economic Indicator Outliers

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = filtered_econ_indicator_df['cpi_index'].quantile(0.25)
Q3 = filtered_econ_indicator_df['cpi_index'].quantile(0.75)

# Interquartile range (IQR)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_cpi = filtered_econ_indicator_df[(filtered_econ_indicator_df['cpi_index'] < lower_bound) | 
                                      (filtered_econ_indicator_df['cpi_index'] > upper_bound)]['cpi_index']

print(outliers_cpi)
# Out:
# Series([], Name: cpi_index, dtype: float64)

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = filtered_econ_indicator_df['nonfarm_payroll_per_thousand'].quantile(0.25)
Q3 = filtered_econ_indicator_df['nonfarm_payroll_per_thousand'].quantile(0.75)

# Interquartile range (IQR)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_nonfarm_payroll = filtered_econ_indicator_df[(filtered_econ_indicator_df['nonfarm_payroll_per_thousand'] < lower_bound) | 
                                      (filtered_econ_indicator_df['nonfarm_payroll_per_thousand'] > upper_bound)]['nonfarm_payroll_per_thousand']

print(outliers_nonfarm_payroll)
# Out:
# Series([], Name: nonfarm_payroll_per_thousand, dtype: float64)

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = filtered_econ_indicator_df['retail_sale_per_millions$'].quantile(0.25)
Q3 = filtered_econ_indicator_df['retail_sale_per_millions$'].quantile(0.75)

# Interquartile range (IQR)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_retail_sales = filtered_econ_indicator_df[(filtered_econ_indicator_df['retail_sale_per_millions$'] < lower_bound) | 
                                      (filtered_econ_indicator_df['retail_sale_per_millions$'] > upper_bound)]['retail_sale_per_millions$']

print(outliers_retail_sales)
# Out:
# date
# 2022-12-01    649106.0
# 2023-12-01    668957.0
# 2024-05-01    643843.0
# 2024-08-01    637747.0
# Name: retail_sale_per_millions$, dtype: float64

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = filtered_econ_indicator_df['unemployment_percentage'].quantile(0.25)
Q3 = filtered_econ_indicator_df['unemployment_percentage'].quantile(0.75)

# Interquartile range (IQR)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_unemployment = filtered_econ_indicator_df[(filtered_econ_indicator_df['unemployment_percentage'] < lower_bound) | 
                                      (filtered_econ_indicator_df['unemployment_percentage'] > upper_bound)]['unemployment_percentage']

print(outliers_unemployment)
# Out:
# date
# 2009-10-01    10.0
# 2020-04-01    14.8
# 2020-05-01    13.2
# 2020-06-01    11.0
# 2020-07-01    10.2
# Name: unemployment_percentage, dtype: float64

# %% [markdown]
# ## Data Visualization
# ### Economic Indicators

# %%
# Compute correlation matrix
corr_matrix = filtered_econ_indicator_df.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Between Economic Indicators')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns


# Standardize the data (Z-score normalization)
scaler = StandardScaler()
standardized_df = pd.DataFrame(scaler.fit_transform(filtered_econ_indicator_df), 
                               columns=filtered_econ_indicator_df.columns, 
                               index=filtered_econ_indicator_df.index)

# Plot the standardized data
plt.figure(figsize=(10, 6))
sns.lineplot(data=standardized_df, x=standardized_df.index, y='cpi_index', label='CPI (Standardized)')
sns.lineplot(data=standardized_df, x=standardized_df.index, y='nonfarm_payroll_per_thousand', label='Nonfarm Payroll (Standardized)')
sns.lineplot(data=standardized_df, x=standardized_df.index, y='retail_sale_per_millions$', label='Retail Sales (Standardized)')
sns.lineplot(data=standardized_df, x=standardized_df.index, y='unemployment_percentage', label='Unemployment Rate (Standardized)')

plt.title('Standardized Economic Indicators Over Time')
plt.xlabel('Year')
plt.ylabel('Standardized Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Apply Min-Max scaling
minmax_scaler = MinMaxScaler()
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(filtered_econ_indicator_df), 
                         columns=filtered_econ_indicator_df.columns, 
                         index=filtered_econ_indicator_df.index)

# Plot the scaled data
plt.figure(figsize=(10, 6))
sns.lineplot(data=scaled_df, x=scaled_df.index, y='cpi_index', label='CPI (Scaled)')
sns.lineplot(data=scaled_df, x=scaled_df.index, y='nonfarm_payroll_per_thousand', label='Nonfarm Payroll (Scaled)')
sns.lineplot(data=scaled_df, x=scaled_df.index, y='retail_sale_per_millions$', label='Retail Sales (Scaled)')
sns.lineplot(data=scaled_df, x=scaled_df.index, y='unemployment_percentage', label='Unemployment Rate (Scaled)')

plt.title('Scaled Economic Indicators Over Time')
plt.xlabel('Year')
plt.ylabel('Scaled Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# First axis (left) for CPI
ax1.set_xlabel('Year')
ax1.set_ylabel('CPI', color='tab:red')
ax1.plot(filtered_econ_indicator_df.index, filtered_econ_indicator_df['cpi_index'], color='tab:red', label='CPI')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Second axis (right) for Unemployment Rate
ax2 = ax1.twinx()
ax2.set_ylabel('Unemployment Rate', color='tab:blue')
ax2.plot(filtered_econ_indicator_df.index, filtered_econ_indicator_df['unemployment_percentage'], color='tab:blue', label='Unemployment Rate')
ax2.tick_params(axis='y', labelcolor='tab:blue')

plt.title('CPI vs Unemployment Rate Over Time')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# CPI
sns.lineplot(data=filtered_econ_indicator_df, x=filtered_econ_indicator_df.index, y='cpi_index', ax=axs[0, 0])
axs[0, 0].set_title('CPI')

# Nonfarm Payroll
sns.lineplot(data=filtered_econ_indicator_df, x=filtered_econ_indicator_df.index, y='nonfarm_payroll_per_thousand', ax=axs[0, 1])
axs[0, 1].set_title('Nonfarm Payroll')

# Retail Sales
sns.lineplot(data=filtered_econ_indicator_df, x=filtered_econ_indicator_df.index, y='retail_sale_per_millions$', ax=axs[1, 0])
axs[1, 0].set_title('Retail Sales')

# Unemployment Rate
sns.lineplot(data=filtered_econ_indicator_df, x=filtered_econ_indicator_df.index, y='unemployment_percentage', ax=axs[1, 1])
axs[1, 1].set_title('Unemployment Rate')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Visualization
# ### Stocks

# %% [markdown]
# ### Loading the Stocks Data
# First, we will load the stocks data from AWS Athena into a Pandas DataFrame for analysis.

# %%
# Query to retrieve stocks data
stocks_query = """
SELECT * FROM stocks
"""
stocks_df = pd.read_sql(stocks_query, conn)

# Display the first few rows of the DataFrame
stocks_df.head()
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_20992\1607105759.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   stocks_df = pd.read_sql(stocks_query, conn)
#   symbol        date   open    high     low  close   volume
# 0   PFGC  2024-10-11  79.86  81.315  79.770  81.24   634349
# 1   PFGC  2024-10-10  80.23  80.470  79.270  79.92   748720
# 2   PFGC  2024-10-09  80.00  81.050  79.355  80.49  1369305
# 3   PFGC  2024-10-08  78.34  78.575  77.510  78.41   533444
# 4   PFGC  2024-10-07  78.62  78.690  77.780  78.03   555415

# %%
# Drop the specified columns
stocks_df = stocks_df.drop(columns=['open', 'high', 'low'])

# Convert the 'date' column to datetime
stocks_df['date'] = pd.to_datetime(stocks_df['date'])

# Set 'date' as the index
stocks_df.set_index('date', inplace=True)

# Pivot the dataframe if needed
# Assuming 'symbol' is the stock symbol and you want to pivot to have symbols as columns
pivoted_stocks_df = stocks_df.pivot_table(index=stocks_df.index, columns='symbol', values=['close', 'volume'])

# %%
pivoted_stocks_df.head(2)
# Out:
#             close                                                      ...  \
# symbol        ADM   AGCO   ALCO   ANDE  BG BGS BRFS    CAG   CALM  CF  ...
# date                                                                   ...
# 1999-11-01  11.90  10.88  15.25  7.938 NaN NaN  NaN  25.81  3.875 NaN  ...
# 1999-11-02  12.15  10.69  15.13  7.875 NaN NaN  NaN  25.88  3.875 NaN  ...
#
#              volume                                                   \
# symbol          SMG SMPL      STKL        SYY THS     TSCO       TSN
# date
# 1999-11-01  50300.0  NaN   64500.0   951200.0 NaN  13000.0  155700.0
# 1999-11-02  66800.0  NaN  116400.0  1099100.0 NaN   5800.0  261100.0
#
#
# symbol            UL     UNFI  WW
# date
# 1999-11-01  111400.0  24300.0 NaN
# 1999-11-02   68000.0  84900.0 NaN
#
# [2 rows x 88 columns]

# %%
# Filter the pivoted dataframe for dates from 2000 to the present
filtered_stocks_df = pivoted_stocks_df.loc['2000-01-01':]
filtered_stocks_df.head(2)
# Out:
#             close                                                     ...  \
# symbol        ADM   AGCO   ALCO  ANDE  BG BGS BRFS    CAG   CALM  CF  ...
# date                                                                  ...
# 2000-01-03  12.00  12.25  16.38  8.19 NaN NaN  NaN  22.88  3.625 NaN  ...
# 2000-01-04  11.88  12.56  15.88  7.50 NaN NaN  NaN  22.44  3.438 NaN  ...
#
#              volume                                                          \
# symbol          SMG SMPL     STKL       SYY THS    TSCO       TSN        UL
# date
# 2000-01-03  57000.0  NaN  12900.0  616600.0 NaN  8200.0  235200.0  490800.0
# 2000-01-04  42300.0  NaN  36100.0  527100.0 NaN  4200.0  188600.0  123300.0
#
#
# symbol          UNFI  WW
# date
# 2000-01-03  119600.0 NaN
# 2000-01-04   87700.0 NaN
#
# [2 rows x 88 columns]

# %%
filtered_stocks_df.describe()
# Out:
#               close                                                      \
# symbol          ADM         AGCO         ALCO         ANDE           BG
# count   6234.000000  6234.000000  6234.000000  6234.000000  5835.000000
# mean      37.329819    52.790707    33.381084    34.017305    66.559318
# std       18.964892    34.776286    10.099789    16.516507    23.559007
# min        8.313000     8.000000    15.060000     7.000000    15.850000
# 25%       24.750000    22.255000    26.550000    22.465000    53.640000
# 50%       35.830000    48.225000    31.000000    34.850000    66.230000
# 75%       45.250000    65.712500    39.040000    42.990000    80.445000
# max       98.220000   156.600000    64.850000   122.080000   133.000000
#
#                                                                          ...  \
# symbol          BGS         BRFS          CAG         CALM           CF  ...
# count   4378.000000  5982.000000  6234.000000  6234.000000  4825.000000  ...
# ...

# %%
# Check for missing values in the filtered dataframe
missing_values_stocks = filtered_stocks_df.isnull().sum()
missing_values_stocks = missing_values_stocks[missing_values_stocks > 0]
print(missing_values_stocks)
# Out:
#         symbol
# close   BG         399
#         BGS       1856
#         BRFS       252
#         CF        1409
#         CTVA      4878
#         CVGW       638
#         HOGS      4850
#         JBSAY     4069
#         JVA       1339
#         KHC       3899
#         MDLZ       364
#         PFGC      3961
#         POST      3036
#         SMPL      4406
#         THS       1378
#         WW         469
# volume  BG         399
#         BGS       1856
#         BRFS       252
#         CF        1409
#         CTVA      4878
#         CVGW       638
#         HOGS      4850
#         JBSAY     4069
#         JVA       1339
#         KHC       3899
#         MDLZ       364
#         PFGC      3961
#         POST      3036
#         SMPL      4406
#         THS       1378
#         WW         469
# dtype: int64

# %% [markdown]
# Remove Stocks with Excessive Missing Data

# %%
# Set a threshold (e.g., 15% missing rows)
threshold = 0.15 * 6234
stocks_to_remove = missing_values_stocks[missing_values_stocks > threshold].index
filtered_stocks_df.drop(columns=stocks_to_remove, inplace=True)
# Out:
# C:\Users\Mat\AppData\Local\Temp\ipykernel_20992\2530531051.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks_df.drop(columns=stocks_to_remove, inplace=True)

# %%
missing_values_stocks2 = filtered_stocks_df.isnull().sum()
missing_values_stocks2 = missing_values_stocks2[missing_values_stocks2 > 0]
print(missing_values_stocks2)
# Out:
#         symbol
# close   BG        399
#         BRFS      252
#         CVGW      638
#         MDLZ      364
#         WW        469
# volume  BG        399
#         BRFS      252
#         CVGW      638
#         MDLZ      364
#         WW        469
# dtype: int64

# %% [markdown]
# Due to some stocks missing large amount of data, for this analysis, we have filtered them out by creating a threshold for acceptable missing data.
# Further to  add, the remaining missing data will not be imputed by methods like forward fill (ffill), backward fill (bfill), or interpolation, in order to not distort trends andd over-smooth (masking volatility) of key market responses to hurricanes.

# %% [markdown]
# ### Removed stock data

# %% [markdown]
# The following stocks have been removed from the dataframe do to missing data greater than the threshold we set:
# BGS
# CF
# CTVA
# HOGS
# JBSAY
# JVA
# KHC
# MDLZ
# PFGC
# POST
# SMPL
# THS

# %%
filtered_stocks_df.describe()
# Out:
#               close                                                      \
# symbol          ADM         AGCO         ALCO         ANDE           BG
# count   6234.000000  6234.000000  6234.000000  6234.000000  5835.000000
# mean      37.329819    52.790707    33.381084    34.017305    66.559318
# std       18.964892    34.776286    10.099789    16.516507    23.559007
# min        8.313000     8.000000    15.060000     7.000000    15.850000
# 25%       24.750000    22.255000    26.550000    22.465000    53.640000
# 50%       35.830000    48.225000    31.000000    34.850000    66.230000
# 75%       45.250000    65.712500    39.040000    42.990000    80.445000
# max       98.220000   156.600000    64.850000   122.080000   133.000000
#
#                                                                          ...  \
# symbol         BRFS          CAG         CALM         CVGW          DAR  ...
# count   5982.000000  6234.000000  6234.000000  5596.000000  6234.000000  ...
# ...
